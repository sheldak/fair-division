# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import random
import time

from fairdivision.algorithms.ordered_picking import ordered_picking
from fairdivision.experiments.measurements import *
from fairdivision.utils.allocation import Allocation
from fairdivision.utils.checkers import *
from fairdivision.utils.generators import *

# %%
def run_algorithm(n, m, generator, iterations, algorithm, property_name):
    seed = random.randint(1, 100_000_000)
    random.seed(seed)
    
    measurements = []
    
    for _ in range(iterations):
        agents = generate_agents(n)
        items = generate_items(m)
        
        generate_valuations(agents, items, generator)
        
        allocation = algorithm(agents, items)

        if property_name == "EF1":
            measurements.append((ef1_satisfied_factor(agents, allocation), highest_ef1_approximation(agents, allocation)))
        elif property_name == "EFX":
            measurements.append((efx_satisfied_factor(agents, allocation), highest_efx_approximation(agents, allocation)))

    return measurements


def print_property_satisfaction(n, m, measurements, property_name):
    not_satisfied = list(filter(lambda measurement: measurement[1] < 1.0, measurements))

    factors = dict()
    approximations = list()

    for factor, _ in not_satisfied:
        if factor in factors:
            factors[factor] += 1
        else:
            factors[factor] = 1

    print(f"{n} agents and {m} items, {len(not_satisfied)} out of {len(measurements)} not {property_name}\n  factors:        [", end="")
    
    first = True
    for factor, occurrences in sorted(factors.items(), key=lambda pair: pair[0]):
        if not first:
            print(", ", end="")

        if occurrences == 1:
            print(f"{factor} - {occurrences} time", end="")
        else:
            print(f"{factor} - {occurrences} times", end="")

        first = False

    print("]\n  approximations: [", end="")

    first = True
    for _, approximation in sorted(filter(lambda measurement: measurement[1] < 1.0, measurements), reverse=True):
        if not first:
            print(", ", end="")

        print(f"{approximation}", end="")
        
        first = False

    print("]\n")

# %%
n = 5
ms = np.concatenate((np.arange(2, 100, 2), np.arange(100, 1050, 50)))

generator = AdditiveGenerator(min=0, max=100)
# generator = OrderedGenerator(min=0, max=10000)

iterations = 100

for m in ms:
    measurements = run_algorithm(n, m, generator, iterations, ordered_picking, "EFX")
    print_property_satisfaction(n, m, measurements, "EFX")
# Out:
# 5 agents and 2 items, 0 out of 100 not EFX
#   factors:        []
#   approximations: []
#
# 5 agents and 4 items, 0 out of 100 not EFX
#   factors:        []
#   approximations: []
#
# 5 agents and 6 items, 1 out of 100 not EFX
#   factors:        [0.8 - 1 time]
#   approximations: [0.733]
#
# 5 agents and 8 items, 26 out of 100 not EFX
#   factors:        [0.2 - 1 time, 0.4 - 6 times, 0.6 - 8 times, 0.8 - 11 times]
#   approximations: [0.986, 0.948, 0.946, 0.753, 0.698, 0.686, 0.658, 0.645, 0.603, 0.595, 0.586, 0.867, 0.817, 0.718, 0.693, 0.68, 0.672, 0.662, 0.559, 0.886, 0.848, 0.687, 0.655, 0.537, 0.517, 0.729]
#
# 5 agents and 10 items, 37 out of 100 not EFX
#   factors:        [0.6 - 12 times, 0.8 - 25 times]
#   approximations: [0.988, 0.979, 0.971, 0.967, 0.965, 0.938, 0.923, 0.903, 0.845, 0.843, 0.829, 0.807, 0.795, 0.772, 0.772, 0.758, 0.752, 0.683, 0.665, 0.664, 0.653, 0.649, 0.618, 0.584, 0.574, 0.946, 0.881, 0.833, 0.782, 0.764, 0.746, 0.692, 0.687, 0.683, 0.619, 0.562, 0.555]
#
# 5 agents and 12 items, 23 out of 100 not EFX
#   factors:        [0.6 - 2 times, 0.8 - 21 times]
#   approximations: [0.994, 0.994, 0.986, 0.978, 0.975, 0.975, 0.974, 0.973, 0.965, 0.965, 0.963, 0.957, 0.948, 0.935, 0.935, 0.925, 0.905, 0.852, 0.838, 0.747, 0.744, 0.935, 0.763]
#
# 5 agents and 14 items, 12 out of 100 not EFX
#   factors:        [0.8 - 12 times]
#   approximations: [0.985, 0.962, 0.96, 0.94, 0.933, 0.918, 0.898, 0.871, 0.856, 0.833, 0.814, 0.739]
#
# 5 agents and 16 items, 8 out of 100 not EFX
#   factors:        [0.6 - 1 time, 0.8 - 7 times]
#   approximations: [0.945, 0.937, 0.935, 0.901, 0.891, 0.792, 0.77, 0.832]
#
# 5 agents and 18 items, 5 out of 100 not EFX
#   factors:        [0.8 - 5 times]
#   approximations: [0.992, 0.972, 0.936, 0.883, 0.848]
#
# 5 agents and 20 items, 7 out of 100 not EFX
#   factors:        [0.8 - 7 times]
#   approximations: [0.99, 0.988, 0.932, 0.928, 0.925, 0.906, 0.861]
#
# 5 agents and 22 items, 5 out of 100 not EFX
#   factors:        [0.8 - 5 times]
#   approximations: [0.993, 0.933, 0.899, 0.899, 0.89]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 10
#       7 iterations = 100
#       9 for m in ms:
# ---> 10     measurements = run_algorithm(n, m, generator, iterations, ordered_picking, "EFX")
#      11     print_property_satisfaction(n, m, measurements, "EFX")
#      12     # print(f"{m}: {measurements}")
#
# Cell In[66], line 13, in run_algorithm(n, m, generator, iterations, algorithm, property_name)
#       9 items = generate_items(m)
#      11 generate_valuations(agents, items, generator)
# ---> 13 allocation = algorithm(agents, items)
#      15 if property_name == "EF1":
#      16     measurements.append((ef1_satisfied_factor(agents, allocation), highest_ef1_approximation(agents, allocation)))
#
# File ~/au/master_thesis/fair_division/fairdivision/algorithms/ordered_picking.py:37, in ordered_picking(agents, items)
#      34 ordered_items = generate_items(items.size(), items.size() + 1)
#      35 assign_valuations_in_order(agents, items, ordered_items)
# ---> 37 allocation_for_ordered = envy_cycle_elimination(agents, Allocation(agents), ordered_items)
#      39 picking_sequence = get_picking_sequence(ordered_items, allocation_for_ordered)
#      41 return pick_items(agents, items, picking_sequence)
#
# File ~/au/master_thesis/fair_division/fairdivision/algorithms/envy_cycle_elimination.py:26, in envy_cycle_elimination(agents, allocation, items)
#      24 while unenvied_agent is None:
#      25     cycle = nx.find_cycle(graph)
# ---> 26     graph = eliminate_cycle(agents, cycle, allocation)
#      28     unenvied_agent = get_unenvied_agent(graph, agents, allocation)
#      30 favorite_item = unenvied_agent.get_favorite_item(items_left)
#
# File ~/au/master_thesis/fair_division/fairdivision/algorithms/envy_cycle_elimination.py:97, in eliminate_cycle(agents, cycle, allocation)
#      93     allocation.allocate_bundle(envious, allocation.for_agent(envied))
#      95 allocation.allocate_bundle(cycle[-1][0], first_bundle)
# ---> 97 return create_envy_graph(agents, allocation)
#
# File ~/au/master_thesis/fair_division/fairdivision/algorithms/envy_cycle_elimination.py:57, in create_envy_graph(agents, allocation)
#      55 for agent_i in agents:
#      56     for agent_j in possibly_envied_agents:
# ---> 57         if agent_i.envies(agent_j, allocation):
#      58             graph.add_edge(agent_i, agent_j)
#      60 return graph
#
# File ~/au/master_thesis/fair_division/fairdivision/utils/agent.py:73, in Agent.envies(self, other, allocation)
#      72 def envies(self, other: Agent, allocation: Allocation) -> bool:
# ---> 73     self_valuation = self.get_valuation(allocation.for_agent(self))
#      74     other_valuation = self.get_valuation(allocation.for_agent(other))
#      76     return other_valuation > self_valuation
#
# File ~/au/master_thesis/fair_division/fairdivision/utils/agent.py:48, in Agent.get_valuation(self, item_or_bundle)
#      46 if isinstance(item_or_bundle, Bundle) and self.valuations_additive:
#      47     valuation = 0
# ---> 48     for item in item_or_bundle:
#      49         valuation += self.valuations[item]
#      51     return valuation
#
# File ~/au/master_thesis/fair_division/fairdivision/utils/bundle.py:41, in Bundle.__iter__(self)
#      40 def __iter__(self) -> Iterator[Item]:
# ---> 41     return self.items.__iter__()
#
# File ~/au/master_thesis/fair_division/fairdivision/utils/items.py:25, in Items.__iter__(self)
#      24 def __iter__(self) -> Iterator[Item]:
# ---> 25     return self.get_items().__iter__()
#
# File ~/au/master_thesis/fair_division/fairdivision/utils/items.py:65, in Items.get_items(self)
#      62     else:
#      63         raise Exception(f"To delete an item from items, index or Item object was expected, got {index_or_item}")
# ---> 65 def get_items(self) -> list[Item]:
#      66     return self.sorted_items
#      68 def get_indices(self) -> list[int]:
#
# KeyboardInterrupt:
